# %% [markdown]
# # Test PDF Extraction
# Testing the `extract_text_images_tables` function on a sample NACCER proposal

# %%
from scripts.doc_extractor import extract_text_images_tables
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.

# %%
# Test extraction on NACCER proposal
file_path = 'documents/NACCER_2024_RD_8535.pdf'
doc_list = extract_text_images_tables(file_path)
# Out:
# 2025-11-27 20:21:49,291 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-11-27 20:21:49,409 - INFO - Going to convert document batch...
# 2025-11-27 20:21:49,409 - INFO - Initializing pipeline for StandardPdfPipeline with options hash 2c28ec89b014192881c35ecb45b96fd8
# 2025-11-27 20:21:49,426 - INFO - Loading plugin 'docling_defaults'
# 2025-11-27 20:21:49,436 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2025-11-27 20:21:49,447 - INFO - Loading plugin 'docling_defaults'
# 2025-11-27 20:21:49,466 - INFO - Registered ocr engines: ['auto', 'easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2025-11-27 20:21:50,906 - INFO - Accelerator device: 'cuda:0'
# [INFO] 2025-11-27 20:21:50,938 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2025-11-27 20:21:50,970 [RapidOCR] download_file.py:60: File exists and is valid: /home/saad1926q/nexml-rag/.venv/lib/python3.10/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.onnx
# ...

# %%
# Print results
print(f"Number of documents: {len(doc_list)}")
print("\n" + "="*80 + "\n")

for i, doc in enumerate(doc_list):
    print(f"Document {i+1}:")
    print(f"Metadata: {doc.metadata}")
    print(f"\nContent length: {len(doc.page_content)} characters")
    print(doc.page_content)
    print("\n" + "="*80 + "\n")
# Out:
# Number of documents: 1
#
# ...
#
# Document 1:
# Metadata: {'source': 'documents/NACCER_2024_RD_8535.pdf'}
#
# Content length: 1229 characters
# ## Research Proposal: NACCER/2024/RD/8535
#
# ## Optimization of Flotation Process for Waste Minimization
#
# | Principal Investigator:   | Dr. Lakshmi Mehta   |
# |---------------------------|---------------------|
# | Institution:              | IISc Bangalore      |
# | Research Area:            | Mine Planning       |
# | Funding Source:           | CIL                 |
# | Duration:                 | 18 months           |
# | Submission Date:          | 2024-01-21          |
#
# ## Abstract
#
# ...

# %%
# Print full content (optional - can be very long)
print("Full extracted text:\n")
print(doc_list[0].page_content)
